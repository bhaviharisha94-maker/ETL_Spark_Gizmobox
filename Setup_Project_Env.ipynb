-- %%
%fs
ls 'abfss://gizmobox@dbudemyextdatalake.dfs.core.windows.net/landing/external_data/'

-- %%
create external location if not exists databricks_udemy_gizmobox
url 'abfss://gizmobox@dbudemyextdatalake.dfs.core.windows.net/'
with (storage credential db_udemy_ext_sc)
  COMMENT 'External Location for dbudemyext_gizmobox'

-- %%
show catalogs

-- %%
create catalog if not exists gizmobox
managed location 'abfss://gizmobox@dbudemyextdatalake.dfs.core.windows.net/'
comment 'Gizmobox Catalog'

-- %%
select current_catalog ();

-- %%
create schema if not exists landing
managed location 'abfss://gizmobox@dbudemyextdatalake.dfs.core.windows.net/landing'
comment 'landing schema';

create schema if not exists bronze
managed location 'abfss://gizmobox@dbudemyextdatalake.dfs.core.windows.net/bronze'
comment 'bronze schema';

create schema if not exists silver
managed location 'abfss://gizmobox@dbudemyextdatalake.dfs.core.windows.net/silver'
comment 'silver schema';

create schema if not exists gold
managed location 'abfss://gizmobox@dbudemyextdatalake.dfs.core.windows.net/gold'
comment 'gold schema';

-- %%
show volumes;

-- %%
use catalog gizmobox;
use schema landing;

create external volume if not exists operational_data
    location 'abfss://gizmobox@dbudemyextdatalake.dfs.core.windows.net/landing/operational_data'
    comment 'operational data volume';

-- %%
%fs ls /Volumes/gizmobox/landing/operational_data/addresses

-- %%
show catalogs
